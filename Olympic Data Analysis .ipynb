# %% [markdown]
# ### Importing Pandas

# %%
import pandas

# %%
pandas.__version__
#pandas version
# Out:
# '1.3.4'

# %%
pandas.show_versions()
#python whole version
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 945c9ed766a61c7d2c0a7cbb251b6edebf9cb7d5
# python           : 3.9.7.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19042
# machine          : AMD64
# processor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.3.4
# numpy            : 1.20.3
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.2.4
# setuptools       : 58.0.4
# Cython           : 0.29.24
# pytest           : 6.2.4
# hypothesis       : None
# sphinx           : 4.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 3.0.1
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.29.0
# ...

# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.4'

# %% [markdown]
# ### Pandas Documentation

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 945c9ed766a61c7d2c0a7cbb251b6edebf9cb7d5
# python           : 3.9.7.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19042
# machine          : AMD64
# processor        : Intel64 Family 6 Model 142 Stepping 10, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.3.4
# numpy            : 1.20.3
# pytz             : 2021.3
# dateutil         : 2.8.2
# pip              : 21.2.4
# setuptools       : 58.0.4
# Cython           : 0.29.24
# pytest           : 6.2.4
# hypothesis       : None
# sphinx           : 4.2.0
# blosc            : None
# feather          : None
# xlsxwriter       : 3.0.1
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# IPython          : 7.29.0
# ...

# %%
pd.read_csv?

# %% [markdown]
# ### Series and DataFrames

# %%
oo=pd.read_csv('C:/Users/dp056738/Desktop/Ex_Files_Pandas_EssT/Ex_Files_Pandas_EssT/ExerciseFiles/data/olympics.csv', skiprows=10
              )
oo.head()
# Out:
#    Athens  1896  Aquatics  Swimming  CHOROPHAS, Efstathios  GRE  Men  \
# 0  Athens  1896  Aquatics  Swimming          HAJOS, Alfred  HUN  Men
# 1  Athens  1896  Aquatics  Swimming       ANDREOU, Joannis  GRE  Men
# 2  Athens  1896  Aquatics  Swimming  CHOROPHAS, Efstathios  GRE  Men
# 3  Athens  1896  Aquatics  Swimming          NEUMANN, Paul  AUT  Men
# 4  Athens  1896  Aquatics  Swimming      PEPANOS, Antonios  GRE  Men
#
#    1200m freestyle  M  Bronze
# 0  1200m freestyle  M    Gold
# 1  1200m freestyle  M  Silver
# 2   400m freestyle  M  Bronze
# 3   400m freestyle  M    Gold
# 4   400m freestyle  M  Silver

# %% [markdown]
# ### Accessing Dataframes

# %%
oo
# Out:
#         Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE  \
# 0       Athens  1896   Aquatics         Swimming          HAJOS, Alfred  HUN
# 1       Athens  1896   Aquatics         Swimming       ANDREOU, Joannis  GRE
# 2       Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE
# 3       Athens  1896   Aquatics         Swimming          NEUMANN, Paul  AUT
# 4       Athens  1896   Aquatics         Swimming      PEPANOS, Antonios  GRE
# ...        ...   ...        ...              ...                    ...  ...
# 29205  Beijing  2008  Wrestling  Wrestling Gre-R         ENGLICH, Mirko  GER
# 29206  Beijing  2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas  LTU
# 29207  Beijing  2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri  ARM
# 29208  Beijing  2008  Wrestling  Wrestling Gre-R          LOPEZ, Mijain  CUB
# 29209  Beijing  2008  Wrestling  Wrestling Gre-R         BAROEV, Khasan  RUS
#
#        Men  1200m freestyle  M  Bronze
# ...

# %% [markdown]
# ### Accessing Series

# %%
oo['Athens']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29205    Beijing
# 29206    Beijing
# 29207    Beijing
# 29208    Beijing
# 29209    Beijing
# Name: Athens, Length: 29210, dtype: object

# %%
oo.GRE
# Out:
# 0        HUN
# 1        GRE
# 2        GRE
# 3        AUT
# 4        GRE
#         ...
# 29205    GER
# 29206    LTU
# 29207    ARM
# 29208    CUB
# 29209    RUS
# Name: GRE, Length: 29210, dtype: object

# %%
oo[['Aquatics','Swimming']]
# Out:
#         Aquatics         Swimming
# 0       Aquatics         Swimming
# 1       Aquatics         Swimming
# 2       Aquatics         Swimming
# 3       Aquatics         Swimming
# 4       Aquatics         Swimming
# ...          ...              ...
# 29205  Wrestling  Wrestling Gre-R
# 29206  Wrestling  Wrestling Gre-R
# 29207  Wrestling  Wrestling Gre-R
# 29208  Wrestling  Wrestling Gre-R
# 29209  Wrestling  Wrestling Gre-R
#
# [29210 rows x 2 columns]

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo.Athens
)
# Out:
# pandas.core.series.Series

# %%
type(oo[['Aquatics','Swimming']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Challange 1

# %%
oo
# Out:
#         Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE  \
# 0       Athens  1896   Aquatics         Swimming          HAJOS, Alfred  HUN
# 1       Athens  1896   Aquatics         Swimming       ANDREOU, Joannis  GRE
# 2       Athens  1896   Aquatics         Swimming  CHOROPHAS, Efstathios  GRE
# 3       Athens  1896   Aquatics         Swimming          NEUMANN, Paul  AUT
# 4       Athens  1896   Aquatics         Swimming      PEPANOS, Antonios  GRE
# ...        ...   ...        ...              ...                    ...  ...
# 29205  Beijing  2008  Wrestling  Wrestling Gre-R         ENGLICH, Mirko  GER
# 29206  Beijing  2008  Wrestling  Wrestling Gre-R   MIZGAITIS, Mindaugas  LTU
# 29207  Beijing  2008  Wrestling  Wrestling Gre-R        PATRIKEEV, Yuri  ARM
# 29208  Beijing  2008  Wrestling  Wrestling Gre-R          LOPEZ, Mijain  CUB
# 29209  Beijing  2008  Wrestling  Wrestling Gre-R         BAROEV, Khasan  RUS
#
#        Men  1200m freestyle  M  Bronze
# ...

# %%
oo.Athens
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29205    Beijing
# 29206    Beijing
# 29207    Beijing
# 29208    Beijing
# 29209    Beijing
# Name: Athens, Length: 29210, dtype: object

# %%
oo['Athens']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29205    Beijing
# 29206    Beijing
# 29207    Beijing
# 29208    Beijing
# 29209    Beijing
# Name: Athens, Length: 29210, dtype: object

# %%
type(oo.Athens)
# Out:
# pandas.core.series.Series

# %%
oo[['Athens','Swimming','GRE']]
# Out:
#         Athens         Swimming  GRE
# 0       Athens         Swimming  HUN
# 1       Athens         Swimming  GRE
# 2       Athens         Swimming  GRE
# 3       Athens         Swimming  AUT
# 4       Athens         Swimming  GRE
# ...        ...              ...  ...
# 29205  Beijing  Wrestling Gre-R  GER
# 29206  Beijing  Wrestling Gre-R  LTU
# 29207  Beijing  Wrestling Gre-R  ARM
# 29208  Beijing  Wrestling Gre-R  CUB
# 29209  Beijing  Wrestling Gre-R  RUS
#
# [29210 rows x 3 columns]

# %%
type(oo[['Athens','Swimming','GRE']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Data Input and Validation

# %%
oo=pd.read_csv('C:/Users/dp056738/Desktop/Ex_Files_Pandas_EssT/Ex_Files_Pandas_EssT/ExerciseFiles/data/olympics.csv',skiprows=4)
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# ### Overview and Validation of data

# %%
oo.shape
# Out:
# (29216, 10)

# %%
#no of rows
oo.shape[0]
# Out:
# 29216

# %%
#no of columns
oo.shape[1]
# Out:
# 10

# %%
oo.head(0)
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
oo.tail(0)
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
oo.head(
)
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.head(3)
# Out:
#      City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming  DRIVAS, Dimitrios  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# ## value_counts()

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1912     885
# 1956     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True,dropna=False)
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %% [markdown]
# ## sort_values()

# %%
ath = oo.Athlete.sort_values()
ath
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# ### Boolean Indexing

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[(oo.Medal=='Gold') & (oo.Gender=='Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# ### String Handling

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %% [markdown]
# ### Challenge 2

# %%
oo[oo.Athlete =='Owens, Jesse']
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []

# %%
oo[(oo.Medal=='Gold') & (oo.Gender=='Men') & (oo.Discipline=='singles badminton')]
# Out:
# Empty DataFrame
# Columns: [City, Edition, Sport, Discipline, Athlete, NOC, Gender, Event, Event_gender, Medal]
# Index: []
